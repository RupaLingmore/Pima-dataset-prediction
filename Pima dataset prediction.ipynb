# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Downloads/pima_diabities.csv')

# %%
df.head()
# Out:
#    Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %%
df.dtypes
# Out:
# Preg       int64
# Plas       int64
# Pres       int64
# skin       int64
# test       int64
# mass     float64
# pedi     float64
# age        int64
# class      int64
# dtype: object

# %%
df['mass']=df['mass'].astype('int64')
df['pedi']=df['pedi'].astype('int64')

# %%
df.dtypes
# Out:
# Preg     int64
# Plas     int64
# Pres     int64
# skin     int64
# test     int64
# mass     int64
# pedi     int64
# age      int64
# class    int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Preg', 'Plas', 'Pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class'], dtype='object')

# %%
df.shape
# Out:
# (768, 9)

# %%
df.describe().T
# Out:
#        count        mean         std   min   25%    50%     75%    max
# Preg   768.0    3.845052    3.369578   0.0   1.0    3.0    6.00   17.0
# Plas   768.0  120.894531   31.972618   0.0  99.0  117.0  140.25  199.0
# Pres   768.0   69.105469   19.355807   0.0  62.0   72.0   80.00  122.0
# skin   768.0   20.536458   15.952218   0.0   0.0   23.0   32.00   99.0
# test   768.0   79.799479  115.244002   0.0   0.0   30.5  127.25  846.0
# mass   768.0   31.548177    7.860602   0.0  27.0   32.0   36.00   67.0
# pedi   768.0    0.071615    0.277494   0.0   0.0    0.0    0.00    2.0
# age    768.0   33.240885   11.760232  21.0  24.0   29.0   41.00   81.0
# class  768.0    0.348958    0.476951   0.0   0.0    0.0    1.00    1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Preg    768 non-null    int64
#  1   Plas    768 non-null    int64
#  2   Pres    768 non-null    int64
#  3   skin    768 non-null    int64
#  4   test    768 non-null    int64
#  5   mass    768 non-null    int64
#  6   pedi    768 non-null    int64
#  7   age     768 non-null    int64
#  8   class   768 non-null    int64
# dtypes: int64(9)
# memory usage: 54.1 KB

# %%
df.isnull().sum()
# Out:
# Preg     0
# Plas     0
# Pres     0
# skin     0
# test     0
# mass     0
# pedi     0
# age      0
# class    0
# dtype: int64

# %%
df.skew()
# Out:
# Preg     0.901674
# Plas     0.173754
# Pres    -1.843608
# skin     0.109372
# test     2.272251
# mass    -0.384770
# pedi     4.039350
# age      1.129597
# class    0.635017
# dtype: float64

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(12,10))
df.boxplot()
plt.show()

# %%
plt.pie(df['class'].value_counts(normalize=True)*100,labels=['not having dia','having dai'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1f7802de6d0>,
#   <matplotlib.patches.Wedge at 0x1f7802debe0>],
#  [Text(-0.5025941410457841, 0.9784677457057288, 'not having dia'),
#   Text(0.502593957824251, -0.9784678398182308, 'having dai')])

# %%
df.corr()
# Out:
#            Preg      Plas      Pres      skin      test      mass      pedi  \
# Preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.016501 -0.014610
# Plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.218293  0.133843
# Pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.279822  0.066559
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.393608  0.122670
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197368  0.119496
# mass   0.016501  0.218293  0.279822  0.393608  0.197368  1.000000  0.109890
# pedi  -0.014610  0.133843  0.066559  0.122670  0.119496  0.109890  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.034266  0.032661
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292494  0.126164
#
#             age     class
# Preg   0.544341  0.221898
# Plas   0.263514  0.466581
# Pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.034266  0.292494
# pedi   0.032661  0.126164
# age    1.000000  0.238356
# class  0.238356  1.000000

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
x=df.drop(['class'],axis=1)
y=df['class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=41)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_true,y_pred=y_test,lr.predict(x_test)
# Out:
# C:\Users\Rupa\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,roc_curve,precision_score,recall_score,f1_score

# %%
lr.score(x_train,y_train)*100   #training accuracy
# Out:
# 77.68729641693811

# %%
lr.score(x_test,y_test)*100   #testing accuracy
# Out:
# 79.22077922077922

# %%
accuracy_score(y_true,y_pred)*100
# Out:
# 79.22077922077922

# %%
sns.heatmap(confusion_matrix(y_true,y_pred),annot=True)
plt.title("confusion matrix")
plt.xlabel("actual value")
plt.ylabel("predicted value")
# Out:
# Text(33.0, 0.5, 'predicted value')

# %%
tnr,tpr,_=roc_curve(y_true,y_pred)
plt.plot(tnr,tpr)
plt.title("ROC AUC Curve")
plt.xlabel("Specificity")
plt.ylabel("sensitivity")
# Out:
# Text(0, 0.5, 'sensitivity')

# %%
precision_score(y_true,y_pred)*100
# Out:
# 79.48717948717949

# %%
recall_score(y_true,y_pred)*100
# Out:
# 56.36363636363636

# %%
f1_score(y_true,y_pred)*100
# Out:
# 65.95744680851064
